# %%
# Author:       Andrey Norin
# Title :       Scrape Suffolk County Real Estate Listings
# Date Created: 11/20/2022
# Date Updated: 11/26/2022
# based on tutorial: https://medium.com/@knappik.marco/python-web-scraping-how-to-scrape-the-api-of-a-real-estate-website-dc8136e56249

# %%
from datetime import date
import requests 
import json 
import pandas as pd

# %%
# set export file details
todaysDate = str(date.today())
countyName = "Suffolk"
csvFileName = (countyName + "_" + todaysDate + ".csv")

# %%
def send_request(page_number: int, offset_parameter: int):
    url = "https://www.realtor.com/api/v1/hulk?client_id=rdc-x&schema=vesta"
    headers = {"content-type": "application/json"}

    body = r'{"query":"\nquery ConsumerSearchQuery($query: HomeSearchCriteria!) {\n  rich_snippets: home_search(query: $query,\n    sort:{field: home_phrases_score, direction: desc},\n    limit: 20,\n  ){\n    count\n    total\n    results {\n      property_id\n      list_price\n      description {\n        beds\n        baths\n        baths_full\n        baths_half\n        baths_3qtr\n        sqft\n      }\n      primary_photo(https: true) {\n        href\n      }\n      permalink\n      href\n      flags {\n        is_pending\n        is_foreclosure\n        is_contingent\n        is_new_construction\n        is_new_listing (days: 14)\n        is_price_reduced (days: 30)\n        is_plan\n      }\n      location {\n        address {\n          city\n          country\n          line\n          postal_code\n          state_code\n          state\n        }\n      }\n      open_houses {\n        start_date\n        end_date\n      }\n      sentences_list: highlights(highlight_type: phrase_srp_spl_homes) {\n        ... on HighlightPhrase {\n          phrase\n          text\n        }\n      }\n    }\n  }\n}","callfrom":"SRP","nrQueryType":"SPECIAL_FEATURES","cacheKey":"SPECIAL_FEATURES","cacheParams":"/special_features/Suffolk-County_NY","variables":{"query":{"search_location":{"location":"Suffolk County, NY"},"status":"for_sale"}},"isClient":true}'
    json_body = json.loads(body)

    json_body["variables"]["page_index"] = page_number
    json_body["seoPayload"] = page_number
    json_body["variables"]["offset"] = offset_parameter

    r = requests.post(url=url, json=json_body, headers=headers)
    json_data = r.json()
    return json_data

# %%
offset_parameter = 0

json_data_list = []

for page_number in range(1, 151):
    json_data = send_request(page_number=page_number, offset_parameter=offset_parameter)
    json_data_list.append(json_data)
    offset_parameter +=42

# %%
def extract_features(entry: dict):
    feature_dict = {
        "id": entry["property_id"],
        "price": entry["list_price"],
        "beds": entry["description"]["beds"],
        "baths": entry["description"]["baths"],
        "sqft": entry["description"]["sqft"],
        "address": entry["location"]["address"]["line"],
        "postal_code": entry["location"]["address"]["postal_code"],
        "state": entry["location"]["address"]["state_code"],
        "city": entry["location"]["address"]["city"]
    }

    return feature_dict

# %%
feature_dict_list = []

for data in json_data_list:
    for entry in data['data']['rich_snippets']['results']:
        feature_dict = extract_features(entry=entry)
        feature_dict_list.append(feature_dict)

df = pd.DataFrame(feature_dict_list)

# %%
# export csv file
df.to_csv(csvFileName)

# %%
df.head(100)
# Out:
#             id     price  beds  baths     sqft                   address  \
# 0   4320632096   3995000     7      7   6400.0            3 Discovery Ln
# 1   4528089672   2699000     4      4   2700.0          12 Bay Meadow Ln
# 2   4560478667    975000     4      5   3600.0  34 Jefferson Landing Cir
# 3   4622503716    400000     3      2      NaN            50 Beecher Ave
# 4   4355382664   2475000     5      4      NaN            87 Wildwood Dr
# ..         ...       ...   ...    ...      ...                       ...
# 95  4697368030    875000     3      2      NaN           516 Madison Ave
# 96  3542840089   1095000     4      3      NaN          505 Saltaire Way
# 97  4068836272  18995000     6      8   8000.0              67 Hither Ln
# 98  3651483610   4495000     4      6   3196.0               55 Gould St
# 99  9135534016  27500000    11     17  23000.0          802 Town Line Rd
#
#    postal_code state            city
# 0        11937    NY    East Hampton
# 1        11977    NY     Westhampton
# 2        11777    NY  Port Jefferson
# 3        11730    NY      East Islip
# 4        11746    NY       Dix Hills
# ..         ...   ...             ...
# 95       11944    NY       Greenport
# 96       11952    NY       Mattituck
# 97       11937    NY    East Hampton
# 98       11937    NY    East Hampton
# 99       11962    NY      Sagaponack
#
# [100 rows x 9 columns]

# %%
json_data
# Out:
# {'data': {'rich_snippets': {'count': 20,
#    'total': 6929,
#    'results': [{'property_id': '4320632096',
#      'list_price': 3995000,
#      'description': {'beds': 7,
#       'baths': 7,
#       'baths_full': 7,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 6400},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/2b6b8552ecfaa94b635dc1e7e9d63b17l-m4176403864s.jpg'},
#      'permalink': '3-Discovery-Ln_East-Hampton_NY_11937_M43206-32096',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/3-Discovery-Ln_East-Hampton_NY_11937_M43206-32096',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '3 Discovery Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spacious second floor primary suite offers water views of Three Mile Harbor',
#        'text': "The spacious second floor primary suite offers water views of Three Mile Harbor from it's own balcony."},
#       {'phrase': 'own balcony',
#        'text': "The spacious second floor primary suite offers water views of Three Mile Harbor from it's own balcony."},
#       {'phrase': 'large gunite pool with spa',
#        'text': 'The large gunite pool with spa is bordered by a generous side lawn.'},
#       {'phrase': 'generous side lawn',
#        'text': 'The large gunite pool with spa is bordered by a generous side lawn.'},
#       {'phrase': 'outdoor kitchen',
#        'text': 'This flows seamlessly out to a covered poolside patio for entertaining, with an outdoor kitchen and another fireplace.'},
#       {'phrase': 'covered poolside patio',
#        'text': 'This flows seamlessly out to a covered poolside patio for entertaining, with an outdoor kitchen and another fireplace.'},
#       {'phrase': 'dramatic fireplace',
#        'text': 'Upon entering the home, you are welcomed by a light-filled great room with large windows and a dramatic fireplace.'},
#       {'phrase': 'laundry room',
#        'text': 'On the lower level you will find a full gym, two additional bedrooms and bath and laundry room.'}]},
#     {'property_id': '4528089672',
#      'list_price': 2699000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 2700},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/7ac87c1c8eb34f556d1d99cdd309fe69l-m3515461374s.jpg'},
#      'permalink': '12-Bay-Meadow-Ln_Westhampton_NY_11977_M45280-89672',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/12-Bay-Meadow-Ln_Westhampton_NY_11977_M45280-89672',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Westhampton',
#        'country': 'USA',
#        'line': '12 Bay Meadow Ln',
#        'postal_code': '11977',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': "gourmet chef 's kitchen offers brand new stainless steel appliances",
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'gorgeous quartz waterfall island with seating',
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'lower deck',
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'additional statement piece within the living room',
#        'text': 'The curved staircase presents as an additional statement piece within the living room leading to the upper level.'},
#       {'phrase': 'curved staircase presents',
#        'text': 'The curved staircase presents as an additional statement piece within the living room leading to the upper level.'},
#       {'phrase': 'new deck with pergola',
#        'text': 'The resort-like backyard is truly remarkable with a brand new deck with pergola, heated pool, and jacuzzi.'},
#       {'phrase': 'expansive backyard',
#        'text': 'The family/living room features a gas fireplace, and rows of windows spanning the curved wall to the 21-foot ceilings, offering scenic views of the expansive backyard and copious amounts of natural light.'},
#       {'phrase': 'custom closets',
#        'text': 'The upper level offers stunning bay views from each of the balconied bedrooms that feature spa-inspired en-suite bathrooms and custom closets.'},
#       {'phrase': 'laundry room',
#        'text': 'The main level also offers an en-suite bedroom fully equipped with a loft, and laundry room.'}]},
#     {'property_id': '4560478667',
#      'list_price': 975000,
#      'description': {'beds': 4,
#       'baths': 5,
#       'baths_full': 4,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3600},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/71e9330ab53e76852195d2259018b310l-m2210476280s.jpg'},
#      'permalink': '34-Jefferson-Landing-Cir_Port-Jefferson_NY_11777_M45604-78667',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/34-Jefferson-Landing-Cir_Port-Jefferson_NY_11777_M45604-78667',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Port Jefferson',
#        'country': 'USA',
#        'line': '34 Jefferson Landing Cir',
#        'postal_code': '11777',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'upper level offers Primary suite w Custom marble and stone tile',
#        'text': 'Den/ Media Room Built in110 -Inch Screen, Projector and Speakers , Dual Sided Granite fireplace, wet bar with Thermador wine fridge, upper level offers Primary suite w Custom marble and stone tile, oversized marble shower, Victoria and Albert soaking Tub.'},
#       {'phrase': 'wet bar with Thermador wine fridge',
#        'text': 'Den/ Media Room Built in110 -Inch Screen, Projector and Speakers , Dual Sided Granite fireplace, wet bar with Thermador wine fridge, upper level offers Primary suite w Custom marble and stone tile, oversized marble shower, Victoria and Albert soaking Tub.'},
#       {'phrase': 'Scavolini Italian glass and wood cabinets',
#        'text': 'Refinished wood floors, Scavolini Italian glass and wood cabinets, Sub Zero, Miele Stove, 2 Fisher and Paykal dishwasher Drawers.'}]},
#     {'property_id': '4622503716',
#      'list_price': 400000,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/a63e99427f42ebb4d2b1cd39df540111l-m2947163470s.jpg'},
#      'permalink': '50-Beecher-Ave_East-Islip_NY_11730_M46225-03716',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/50-Beecher-Ave_East-Islip_NY_11730_M46225-03716',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Islip',
#        'country': 'USA',
#        'line': '50 Beecher Ave',
#        'postal_code': '11730',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Ranch home with potential features large eat in kitchen w skylight',
#        'text': 'Ranch home with potential features large eat in kitchen w skylight, backdoor to backyard, living room w/skylight, Andersen bay window.'},
#       {'phrase': '1 car garage',
#        'text': '3 bedrooms, hardwood floors, full basement with bathroom, outside entrance, storage room, washer and dryer, 1 car garage, house needs cash or construction loan.'}]},
#     {'property_id': '4355382664',
#      'list_price': 2475000,
#      'description': {'beds': 5,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/05aa4bee76bb97a6ee6dcbd52769f9f0l-m3081781253s.jpg'},
#      'permalink': '87-Wildwood-Dr_Dix-Hills_NY_11746_M43553-82664',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/87-Wildwood-Dr_Dix-Hills_NY_11746_M43553-82664',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Dix Hills',
#        'country': 'USA',
#        'line': '87 Wildwood Dr',
#        'postal_code': '11746',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'white center island kitchen with honed Danby Imperial Marble',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'entry foyer with panels',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'large walk in pantry',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'formal dining room',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'great storage',
#        'text': 'Upstairs a gorgeous primary bedroom suite w/ electric fireplace, custom designed closets, master bath w/ radiant heat, generous size bedrooms each w/ a WIC, Finished basement w/ rec space, full bath, laundry, wet bar & great storage, Completely loaded backyard w/ Gunite htd, salt pool, outdoor kitchen w/ gas BBQ, cooktop, ice maker, full sink & fridge, covered pavilion, outdoor cedar bathroom, koi pond, prof landscaping, turn key!'}]},
#     {'property_id': '9942955464',
#      'list_price': 1200000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3600},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/bdaf8ccae19201e9ebe9c91aa7598661l-b2756429838s.jpg'},
#      'permalink': '33A-Cove-Rd-A_Huntington_NY_11743_M99429-55464',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/33A-Cove-Rd-A_Huntington_NY_11743_M99429-55464',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Huntington',
#        'country': 'USA',
#        'line': '33A Cove Rd Unit A',
#        'postal_code': '11743',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Gourmet white Kitchen granite counter top with stainless steel top',
#        'text': 'The heart of the house has a Gourmet white Kitchen granite counter top with stainless steel top of the line appliances .'},
#       {'phrase': 'Luxurious Master Suite with tray ceiling wall',
#        'text': 'Luxurious Master Suite with tray ceiling wall of windows with electric blinds & Extraordinary double Walk-in Closet!'},
#       {'phrase': 'Grand 2 Story Entry Way with double closets',
#        'text': 'The Grand 2 Story Entry Way with double closets along with quality moldings and doors Leads Into this Gorgeous 4 Bedroom, 3.5 Bathroom Home.'},
#       {'phrase': 'separate stall shower with double sink vanity',
#        'text': 'The master bath has a sumptuous tub and a separate stall shower with double sink vanity.'},
#       {'phrase': 'sumptuous tub',
#        'text': 'The master bath has a sumptuous tub and a separate stall shower with double sink vanity.'}]},
#     {'property_id': '4068836272',
#      'list_price': 18995000,
#      'description': {'beds': 6,
#       'baths': 8,
#       'baths_full': 7,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 8000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/9349cca6e7b52b85b794a5fab6626a30l-b2618697360s.jpg'},
#      'permalink': '67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '67 Hither Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spectacular gas fireplace with exquisite antique mill work',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'formal living room design is inspired by London',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar and custom high gloss lacquer Varenna mill work',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'oversized upstairs media room',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'high gloss lacquered ceilings with ornamental antique molding',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'formal dining room',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'uber sexy kitchen lounge area',
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': "butler 's pantry",
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': 'spacious main floor primary suite',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'two custom lit closets',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'pool pavilion with full bath',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'south side of the property',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'wide gunite pool',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'wide custom fireplace',
#        'text': "The outdoor living pavilion has 14' soaring ceilings, a 12' granite clad summer kitchen with refrigerator/sink/bbq, a 16' wide custom fireplace with floating hearth and accent lighting, all anchored by a sensational 25' infinity edge gunite salt water spa."},
#       {'phrase': 'double glass entry doors',
#        'text': "The Italian-stone clad postman's walk leads to a steel architectural canopy which floats above the double glass entry doors."},
#       {'phrase': 'front entry garden',
#        'text': 'Upon arrival, visitors are greeted with an impressively scaled 5000 lb sculpture, commissioned for the front entry garden.'},
#       {'phrase': 'proportioned suites with generous closets',
#        'text': 'Guests will enjoy well proportioned suites with generous closets, motion lighting and Duravit baths.'},
#       {'phrase': 'one half car heated garage',
#        'text': 'Additional amenities include surveillance, gym, wine room, sauna, cedar closets, two and one half car heated garage, central vac, smart irrigation, Lutron lighting, and custom audio inside and out.'},
#       {'phrase': 'heated glass roof atrium',
#        'text': 'The exterior design highlights three main areas: The heated glass roof atrium connects the main house via sliding glass walls to the outdoor dining pavilion.'}]},
#     {'property_id': '3781242032',
#      'list_price': 349900,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 1,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 1344},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/5f814bf37dfca74d7d085feaf0231269l-m2787402958s.jpg'},
#      'permalink': '55-Macarthur-Ave_Brentwood_NY_11717_M37812-42032',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/55-Macarthur-Ave_Brentwood_NY_11717_M37812-42032',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Brentwood',
#        'country': 'USA',
#        'line': '55 Macarthur Ave',
#        'postal_code': '11717',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': [{'start_date': '2022-11-27T11:00:00',
#        'end_date': '2022-11-27T15:00:00'},
#       {'start_date': '2022-11-29T17:00:00',
#        'end_date': '2022-11-29T19:00:00'}],
#      'sentences_list': [{'phrase': 'nice wide block with brand new roof and brand new windows',
#        'text': 'North Brentwood colonial on a very nice wide block with brand new roof and brand new windows.'},
#       {'phrase': 'Huge yard', 'text': 'Huge yard at .'}]},
#     {'property_id': '3533730752',
#      'list_price': 667000,
#      'description': {'beds': 4,
#       'baths': 3,
#       'baths_full': 2,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/d87f2965d0ea9d82112e1b258b1d3300l-m2553493474s.jpg'},
#      'permalink': '11-Redleaf-Ln_Commack_NY_11725_M35337-30752',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/11-Redleaf-Ln_Commack_NY_11725_M35337-30752',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': True,
#       'is_plan': None},
#      'location': {'address': {'city': 'Commack',
#        'country': 'USA',
#        'line': '11 Redleaf Ln',
#        'postal_code': '11725',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'levels Features BRAND NEW custom Eat in kitchen',
#        'text': 'Boasts bright open floor plan with vaulted ceilings on both levels Features BRAND NEW custom Eat in kitchen w/light Cabinetry w/soft close draws, S.S.'},
#       {'phrase': 'open floor plan with vaulted ceilings',
#        'text': 'Boasts bright open floor plan with vaulted ceilings on both levels Features BRAND NEW custom Eat in kitchen w/light Cabinetry w/soft close draws, S.S.'},
#       {'phrase': 'Granite counter tops with ample space',
#        'text': 'appliances, Granite counter tops with ample space, backslash, 2.5 baths, windows, all flooring, Boiler, exterior door & kitchen slider, driveway, gutters, walkways, patio pavers, cesspool, washer, dryer, 4 AC units.'}]},
#     {'property_id': '3647622809',
#      'list_price': 639000,
#      'description': {'beds': 6,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/8bb5fa5084b484734e1cf8c6eb8cd13al-m598323910s.jpg'},
#      'permalink': '62-Laurie-Rd_Brentwood_NY_11717_M36476-22809',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/62-Laurie-Rd_Brentwood_NY_11717_M36476-22809',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Brentwood',
#        'country': 'USA',
#        'line': '62 Laurie Rd',
#        'postal_code': '11717',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'new stainless steel appliances surrounded by brand new kitchen with tons',
#        'text': 'This home boasts freshly polished hardwood floors, brand new stainless steel appliances surrounded by brand new kitchen with tons of storage, granite countertop and marble backsplash.'},
#       {'phrase': 'Huge backyard with additional space',
#        'text': 'Huge backyard with additional space behind the fence.'},
#       {'phrase': 'desirable Brentwood neighborhood',
#        'text': 'Welcome to a fully renovated 6 Bedroom, 2 bathroom house in a desirable Brentwood neighborhood.'}]},
#     {'property_id': '4124648059',
#      'list_price': 3495000,
#      'description': {'beds': 5,
#       'baths': 5,
#       'baths_full': 5,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 3877},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/639044074a34c4ced5bc72b3729fb80el-m1166864234s.jpg'},
#      'permalink': '49-Cosdrew-Ln_East-Hampton_NY_11937_M41246-48059',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/49-Cosdrew-Ln_East-Hampton_NY_11937_M41246-48059',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '49 Cosdrew Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Spacious family kitchen with high end Bertazzoni appliances',
#        'text': 'Spacious family kitchen with high end Bertazzoni appliances.'},
#       {'phrase': 'Junior Primary suite',
#        'text': 'There is a Junior Primary suite on the first floor in addition to 4 ensuite bedrooms on the second floor.'},
#       {'phrase': 'beautiful privacy as this property',
#        'text': 'It will have an 18 by 36 gunite pool and beautiful privacy as this property abuts a nature preserve!'},
#       {'phrase': '36 gunite pool',
#        'text': 'It will have an 18 by 36 gunite pool and beautiful privacy as this property abuts a nature preserve!'}]},
#     {'property_id': '3522803057',
#      'list_price': 2595000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/adf6856646cad6fa3ddd09ca618fd314l-m131787748s.jpg'},
#      'permalink': '23-Long-Hill-Rd_East-Hampton_NY_11937_M35228-03057',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/23-Long-Hill-Rd_East-Hampton_NY_11937_M35228-03057',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '23 Long Hill Rd',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': [{'start_date': '2022-11-26T11:30:00',
#        'end_date': '2022-11-26T13:00:00'}],
#      'sentences_list': [{'phrase': 'expansive first floor primary suite offers plenty of privacy',
#        'text': 'The expansive first floor primary suite offers plenty of privacy and a large spa-like bath with new vanities, cabinetry and countertops.'},
#       {'phrase': 'cabinetry and countertops',
#        'text': 'The expansive first floor primary suite offers plenty of privacy and a large spa-like bath with new vanities, cabinetry and countertops.'},
#       {'phrase': 'expansive Timbertech deck',
#        'text': 'Ideal for entertaining, a bank of sliders lead you to a new and expansive Timbertech deck, heated pool and hot tub surrounded by lush landscaping.'},
#       {'phrase': 'hot tub',
#        'text': 'Ideal for entertaining, a bank of sliders lead you to a new and expansive Timbertech deck, heated pool and hot tub surrounded by lush landscaping.'},
#       {'phrase': "chef 's kitchen",
#        'text': "The chef's kitchen features new quartz countertops and high-end appliances."}]},
#     {'property_id': '9200255023',
#      'list_price': 19950000,
#      'description': {'beds': 12,
#       'baths': 12,
#       'baths_full': 12,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 15000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/a65100c13347ce2b0384a95a90ea2379l-m636774261s.jpg'},
#      'permalink': '180-Rose-Hill-Rd_Water-Mill_NY_11976_M92002-55023',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/180-Rose-Hill-Rd_Water-Mill_NY_11976_M92002-55023',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Water Mill',
#        'country': 'USA',
#        'line': '180 Rose Hill Rd',
#        'postal_code': '11976',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'formal dining room with a buffet server and two elegant glass wine displays',
#        'text': 'Fully equipped with a gourmet chefÃ¢â‚¬â„¢s kitchen, and a formal dining room with a buffet server and two elegant glass wine displays.'},
#       {'phrase': 'main level junior master suite',
#        'text': 'The main level junior master suite includes a lounge area with a fireplace, a private balcony, a sizeable walk-in closet, and en-suite bathroom.'},
#       {'phrase': 'private balcony',
#        'text': 'The main level junior master suite includes a lounge area with a fireplace, a private balcony, a sizeable walk-in closet, and en-suite bathroom.'},
#       {'phrase': 'outdoor lounge with a fireplace',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'expansive outdoor patio',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'outdoor kitchen',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'lounge area with a fireplace',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'lavish master suite',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'large balcony',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'additional home office',
#        'text': 'The pool house incorporates an additional indoor/outdoor kitchen, indoor/outdoor lounge, fitness center/yoga studio, additional home office, and full bathroom making entertaining opportunities endless.'},
#       {'phrase': 'formal bar',
#        'text': 'The main level offers a double-height ceiling living room with a formal bar, fireplace, and access to the expansive poolside terrace.'}]},
#     {'property_id': '4154571724',
#      'list_price': 3695000,
#      'description': {'beds': 5,
#       'baths': 6,
#       'baths_full': 5,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3877},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/814167c01f3610830032ad188feab56cl-m1308755400s.jpg'},
#      'permalink': '18-Barnes-Ave_East-Hampton_NY_11937_M41545-71724',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/18-Barnes-Ave_East-Hampton_NY_11937_M41545-71724',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '18 Barnes Ave',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Spacious family kitchen with high end Bertazzoni appliances',
#        'text': 'Spacious family kitchen with high end Bertazzoni appliances.'},
#       {'phrase': '32 gunite pool',
#        'text': 'It will have an 18 by 32 gunite pool.'}]},
#     {'property_id': '4072798171',
#      'list_price': 399000,
#      'description': {'beds': 2,
#       'baths': 2,
#       'baths_full': 1,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 869},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/18c6953d02103c5e76ab17c4642fac39l-m411612604s.jpg'},
#      'permalink': '188-Kingston-Dr_Ridge_NY_11961_M40727-98171',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/188-Kingston-Dr_Ridge_NY_11961_M40727-98171',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Ridge',
#        'country': 'USA',
#        'line': '188 Kingston Dr Unit 188',
#        'postal_code': '11961',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Custom white wood cabinets with soft close drawers',
#        'text': 'Custom white wood cabinets with soft close drawers.'},
#       {'phrase': 'Glen Cove Model with expanded garage space',
#        'text': 'Lovely Glen Cove Model with expanded garage space and pull down attic steps .'},
#       {'phrase': 'attic steps',
#        'text': 'Lovely Glen Cove Model with expanded garage space and pull down attic steps .'},
#       {'phrase': 'Granite counter tops and Stainless appliances',
#        'text': 'Granite counter tops and Stainless appliances.'},
#       {'phrase': 'Rear patio and front',
#        'text': 'Rear patio and front covered porch.'},
#       {'phrase': 'windows and roof',
#        'text': 'The siding, windows and roof have all been replaced 2018.'}]},
#     {'property_id': '4697368030',
#      'list_price': 875000,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/6836c007ed316ae73a948ab5121c1294l-m1936919759s.jpg'},
#      'permalink': '516-Madison-Ave_Greenport_NY_11944_M46973-68030',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/516-Madison-Ave_Greenport_NY_11944_M46973-68030',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Greenport',
#        'country': 'USA',
#        'line': '516 Madison Ave',
#        'postal_code': '11944',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Open floor plan with spacious double height living room centered on wood',
#        'text': 'Open floor plan with spacious double height living room centered on wood burning fireplace.'},
#       {'phrase': 'full width rear deck',
#        'text': 'Inviting front porch and full width rear deck.'},
#       {'phrase': 'front porch',
#        'text': 'Inviting front porch and full width rear deck.'},
#       {'phrase': 'ample room for a pool',
#        'text': 'Light and bright Greenport Village two story Farmhouse set on rarely available deep and very private double lot with ample room for a pool and backing onto Silver Lake preserved land.'}]},
#     {'property_id': '3542840089',
#      'list_price': 1095000,
#      'description': {'beds': 4,
#       'baths': 3,
#       'baths_full': 2,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/f0b512a17c84bb45856968b64a1793a9l-m567448271s.jpg'},
#      'permalink': '505-Saltaire-Way_Mattituck_NY_11952_M35428-40089',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/505-Saltaire-Way_Mattituck_NY_11952_M35428-40089',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Mattituck',
#        'country': 'USA',
#        'line': '505 Saltaire Way',
#        'postal_code': '11952',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'beautiful white shaker kitchen with real marble countertops',
#        'text': 'The first floor boasts a stunning open floor plan, beautiful white shaker kitchen with real marble countertops, great room with gas fireplace and a large master bedroom with stunning en-suite bathroom.'},
#       {'phrase': 'great room with gas fireplace',
#        'text': 'The first floor boasts a stunning open floor plan, beautiful white shaker kitchen with real marble countertops, great room with gas fireplace and a large master bedroom with stunning en-suite bathroom.'},
#       {'phrase': 'ample space for pool',
#        'text': 'Private fully fenced in backyard with ample space for pool!'}]},
#     {'property_id': '4068836272',
#      'list_price': 18995000,
#      'description': {'beds': 6,
#       'baths': 8,
#       'baths_full': 7,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 8000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/9349cca6e7b52b85b794a5fab6626a30l-b2618697360s.jpg'},
#      'permalink': '67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '67 Hither Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spectacular gas fireplace with exquisite antique millwork',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'formal living room design is inspired by London',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar and custom high gloss lacquer Varenna mill work',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'oversized upstairs media room',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'high gloss lacquered ceilings with ornamental antique molding',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'uber sexy kitchen lounge area',
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top-notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': "butler 's pantry",
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top-notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': 'spacious main floor primary suite',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'two custom lit closets',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'pool pavilion with full bath',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'south side of the property',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'wide gunite pool',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'wide custom fireplace',
#        'text': "The outdoor living pavilion has 14' soaring ceilings, a 12' granite clad summer kitchen with refrigerator/sink/bbq, a 16' wide custom fireplace with floating hearth and accent lighting, all anchored by a sensational 25' infinity edge gunite saltwater spa."},
#       {'phrase': 'double glass entry doors',
#        'text': "The Italian-stone clad postman's walk leads to a steel architectural canopy that floats above the double glass entry doors."},
#       {'phrase': 'front entry garden',
#        'text': 'Upon arrival, visitors are greeted with an impressively scaled 5000 lb sculpture, commissioned for the front entry garden.'},
#       {'phrase': 'one half car heated garage',
#        'text': 'Additional amenities include surveillance, gym, wine room, sauna, cedar closets, two and one half car heated garage, central vac, smart irrigation, Lutron lighting, and custom audio inside and out.'},
#       {'phrase': 'heated glass roof atrium',
#        'text': 'The exterior design highlights three main areas: The heated glass roof atrium connects the main house via sliding glass walls to the outdoor dining pavilion.'},
#       {'phrase': 'generous closets',
#        'text': 'Guests will enjoy well-proportioned suites with generous closets, motion lighting and Duravit baths.'},
#       {'phrase': 'formal dining room',
#        'text': 'Enter the grand foyer into a spacious open-concept custom home ideal for family and entertaining with a formal dining room, living room and family room that flow seamlessly from one room to the next.'}]},
#     {'property_id': '3651483610',
#      'list_price': 4495000,
#      'description': {'beds': 4,
#       'baths': 6,
#       'baths_full': 4,
#       'baths_half': 2,
#       'baths_3qtr': None,
#       'sqft': 3196},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/801f48c93dc2151c9b2b29d1193f476fl-b3206596477s.jpg'},
#      'permalink': '55-Gould-St_East-Hampton_NY_11937_M36514-83610',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/55-Gould-St_East-Hampton_NY_11937_M36514-83610',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': True,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '55 Gould St',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': '2 bonus super sleek glass retractable garage doors',
#        'text': 'An added feature to 55 Gould is the attached heated luxury garage that can house up to six cars with 2 bonus super sleek glass retractable garage doors and expertly finished epoxy flooring.'},
#       {'phrase': 'attached heated luxury garage',
#        'text': 'An added feature to 55 Gould is the attached heated luxury garage that can house up to six cars with 2 bonus super sleek glass retractable garage doors and expertly finished epoxy flooring.'},
#       {'phrase': 'retractable pool cover',
#        'text': 'Step outside to your new 18x34 heated gunite pool with spa and salt water filtration and retractable pool cover.'},
#       {'phrase': 'gunite pool with spa',
#        'text': 'Step outside to your new 18x34 heated gunite pool with spa and salt water filtration and retractable pool cover.'},
#       {'phrase': 'luxurious primary suite',
#        'text': 'The second level boasts 3 en-suite bedrooms, the 4th bedroom with full hall bath and the luxurious primary suite with vaulted ceilings, walk-in closet and custom bathroom.'},
#       {'phrase': 'outdoor grill and bar',
#        'text': 'Host your guests around the floating outdoor grill and bar set up or bask in the sun around the pool with gorgeous bluestone hardscape.'},
#       {'phrase': 'pool bath and laundry',
#        'text': 'One of the 2 half baths is located right off the kitchen that is also a pool bath and laundry.'},
#       {'phrase': 'honed carrara waterfall island',
#        'text': 'The first floor includes an inviting entryway, dining room, living room with fireplace, and an over-sized gourmet kitchen with a honed carrara waterfall island that opens into a sun drenched sitting room, making conversation easy when entertaining or just hanging with the iPad and your morning cup of coffee.'}]},
#     {'property_id': '9135534016',
#      'list_price': 27500000,
#      'description': {'beds': 11,
#       'baths': 17,
#       'baths_full': 15,
#       'baths_half': 2,
#       'baths_3qtr': None,
#       'sqft': 23000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/5ac10a3b67942c37eedede3ddb03c3a6l-m214815142s.jpg'},
#      'permalink': '802-Town-Line-Rd_Sagaponack_NY_11962_M91355-34016',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/802-Town-Line-Rd_Sagaponack_NY_11962_M91355-34016',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'Sagaponack',
#        'country': 'USA',
#        'line': '802 Town Line Rd',
#        'postal_code': '11962',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'second floor primary suite features two full bathrooms',
#        'text': 'Encompassing the northern wing of the main residence, the second floor primary suite features two full bathrooms with Polish glass tile floors and full custom marble slabs on the bath and shower walls, massage room, two walk-in closets, a private office/sitting room, and a private balcony.'},
#       {'phrase': 'private balcony',
#        'text': 'Encompassing the northern wing of the main residence, the second floor primary suite features two full bathrooms with Polish glass tile floors and full custom marble slabs on the bath and shower walls, massage room, two walk-in closets, a private office/sitting room, and a private balcony.'},
#       {'phrase': 'lower level kitchen',
#        'text': 'Two ensuite bedrooms are ideally positioned near the lower level kitchen and secondary staircase, which leads up to the main floor gym.'},
#       {'phrase': 'secondary staircase',
#        'text': 'Two ensuite bedrooms are ideally positioned near the lower level kitchen and secondary staircase, which leads up to the main floor gym.'},
#       {'phrase': 'own wet bar',
#        'text': 'The luxurious living room seamlessly transitions into a formal dining area with seating for ten and its own wet bar.'},
#       {'phrase': 'luxurious living room',
#        'text': 'The luxurious living room seamlessly transitions into a formal dining area with seating for ten and its own wet bar.'},
#       {'phrase': 'great room with soaring ceilings',
#        'text': 'With over 19, 000 square feet, the main residence is introduced by an entry foyer leading to a majestic great room with soaring ceilings featuring a double-sided Galvalume Steel Cladded fireplace designed by local Sagaponack artist, Nathan Slate Joseph and floor-to-ceiling windows showcasing unobstructed reserve views.'},
#       {'phrase': 'primary suite',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'separate balcony',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'laundry room',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'custom storage units',
#        'text': "Surrounded by a Madras patio, the 60' x 25' heated salt water gunite pool with 12' x 8' spa offers ample space for poolside relaxation and the professional-sized sunken Har-Tru tennis court is equipped with a hydro underground system and custom storage units."},
#       {'phrase': 'gunite pool',
#        'text': "Surrounded by a Madras patio, the 60' x 25' heated salt water gunite pool with 12' x 8' spa offers ample space for poolside relaxation and the professional-sized sunken Har-Tru tennis court is equipped with a hydro underground system and custom storage units."},
#       {'phrase': 'expansive living area',
#        'text': 'Inside the refurbished structure is an expansive living area, kitchen, full bathroom and additional storage below.'},
#       {'phrase': 'additional storage below',
#        'text': 'Inside the refurbished structure is an expansive living area, kitchen, full bathroom and additional storage below.'},
#       {'phrase': 'stainless steel Boffi cabinets with a multitude',
#        'text': 'The main level hosts a gourmet dine-in kitchen, open to a relaxed seating area, and offers stainless steel Boffi cabinets with a multitude of high-end appliances.'},
#       {'phrase': 'junior suite',
#        'text': 'The first floor is completed by an enclosed wine room, junior suite, office, and two powder rooms.'},
#       {'phrase': 'main living area',
#        'text': 'Set outside the main living area is a patio with outdoor fire pit capable of seating 30 people and accentuated by the complete exterior lighting package.'},
#       {'phrase': 'recreational room with pool table',
#        'text': 'A recreational room with pool table provides access to an outdoor dining area and is joined by an ensuite bedroom.'}]}]}}}

# %%
json_data
# Out:
# {'data': {'rich_snippets': {'count': 20,
#    'total': 6929,
#    'results': [{'property_id': '4320632096',
#      'list_price': 3995000,
#      'description': {'beds': 7,
#       'baths': 7,
#       'baths_full': 7,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 6400},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/2b6b8552ecfaa94b635dc1e7e9d63b17l-m4176403864s.jpg'},
#      'permalink': '3-Discovery-Ln_East-Hampton_NY_11937_M43206-32096',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/3-Discovery-Ln_East-Hampton_NY_11937_M43206-32096',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '3 Discovery Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spacious second floor primary suite offers water views of Three Mile Harbor',
#        'text': "The spacious second floor primary suite offers water views of Three Mile Harbor from it's own balcony."},
#       {'phrase': 'own balcony',
#        'text': "The spacious second floor primary suite offers water views of Three Mile Harbor from it's own balcony."},
#       {'phrase': 'large gunite pool with spa',
#        'text': 'The large gunite pool with spa is bordered by a generous side lawn.'},
#       {'phrase': 'generous side lawn',
#        'text': 'The large gunite pool with spa is bordered by a generous side lawn.'},
#       {'phrase': 'outdoor kitchen',
#        'text': 'This flows seamlessly out to a covered poolside patio for entertaining, with an outdoor kitchen and another fireplace.'},
#       {'phrase': 'covered poolside patio',
#        'text': 'This flows seamlessly out to a covered poolside patio for entertaining, with an outdoor kitchen and another fireplace.'},
#       {'phrase': 'dramatic fireplace',
#        'text': 'Upon entering the home, you are welcomed by a light-filled great room with large windows and a dramatic fireplace.'},
#       {'phrase': 'laundry room',
#        'text': 'On the lower level you will find a full gym, two additional bedrooms and bath and laundry room.'}]},
#     {'property_id': '4528089672',
#      'list_price': 2699000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 2700},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/7ac87c1c8eb34f556d1d99cdd309fe69l-m3515461374s.jpg'},
#      'permalink': '12-Bay-Meadow-Ln_Westhampton_NY_11977_M45280-89672',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/12-Bay-Meadow-Ln_Westhampton_NY_11977_M45280-89672',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Westhampton',
#        'country': 'USA',
#        'line': '12 Bay Meadow Ln',
#        'postal_code': '11977',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': "gourmet chef 's kitchen offers brand new stainless steel appliances",
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'gorgeous quartz waterfall island with seating',
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'lower deck',
#        'text': "The gourmet chef's kitchen offers brand new stainless steel appliances, custom cabinetry, a gorgeous quartz waterfall island with seating, and dining area with two sets of sliding glass doors that open to the upper and lower deck ."},
#       {'phrase': 'additional statement piece within the living room',
#        'text': 'The curved staircase presents as an additional statement piece within the living room leading to the upper level.'},
#       {'phrase': 'curved staircase presents',
#        'text': 'The curved staircase presents as an additional statement piece within the living room leading to the upper level.'},
#       {'phrase': 'new deck with pergola',
#        'text': 'The resort-like backyard is truly remarkable with a brand new deck with pergola, heated pool, and jacuzzi.'},
#       {'phrase': 'expansive backyard',
#        'text': 'The family/living room features a gas fireplace, and rows of windows spanning the curved wall to the 21-foot ceilings, offering scenic views of the expansive backyard and copious amounts of natural light.'},
#       {'phrase': 'custom closets',
#        'text': 'The upper level offers stunning bay views from each of the balconied bedrooms that feature spa-inspired en-suite bathrooms and custom closets.'},
#       {'phrase': 'laundry room',
#        'text': 'The main level also offers an en-suite bedroom fully equipped with a loft, and laundry room.'}]},
#     {'property_id': '4560478667',
#      'list_price': 975000,
#      'description': {'beds': 4,
#       'baths': 5,
#       'baths_full': 4,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3600},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/71e9330ab53e76852195d2259018b310l-m2210476280s.jpg'},
#      'permalink': '34-Jefferson-Landing-Cir_Port-Jefferson_NY_11777_M45604-78667',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/34-Jefferson-Landing-Cir_Port-Jefferson_NY_11777_M45604-78667',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Port Jefferson',
#        'country': 'USA',
#        'line': '34 Jefferson Landing Cir',
#        'postal_code': '11777',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'upper level offers Primary suite w Custom marble and stone tile',
#        'text': 'Den/ Media Room Built in110 -Inch Screen, Projector and Speakers , Dual Sided Granite fireplace, wet bar with Thermador wine fridge, upper level offers Primary suite w Custom marble and stone tile, oversized marble shower, Victoria and Albert soaking Tub.'},
#       {'phrase': 'wet bar with Thermador wine fridge',
#        'text': 'Den/ Media Room Built in110 -Inch Screen, Projector and Speakers , Dual Sided Granite fireplace, wet bar with Thermador wine fridge, upper level offers Primary suite w Custom marble and stone tile, oversized marble shower, Victoria and Albert soaking Tub.'},
#       {'phrase': 'Scavolini Italian glass and wood cabinets',
#        'text': 'Refinished wood floors, Scavolini Italian glass and wood cabinets, Sub Zero, Miele Stove, 2 Fisher and Paykal dishwasher Drawers.'}]},
#     {'property_id': '4622503716',
#      'list_price': 400000,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/a63e99427f42ebb4d2b1cd39df540111l-m2947163470s.jpg'},
#      'permalink': '50-Beecher-Ave_East-Islip_NY_11730_M46225-03716',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/50-Beecher-Ave_East-Islip_NY_11730_M46225-03716',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Islip',
#        'country': 'USA',
#        'line': '50 Beecher Ave',
#        'postal_code': '11730',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Ranch home with potential features large eat in kitchen w skylight',
#        'text': 'Ranch home with potential features large eat in kitchen w skylight, backdoor to backyard, living room w/skylight, Andersen bay window.'},
#       {'phrase': '1 car garage',
#        'text': '3 bedrooms, hardwood floors, full basement with bathroom, outside entrance, storage room, washer and dryer, 1 car garage, house needs cash or construction loan.'}]},
#     {'property_id': '4355382664',
#      'list_price': 2475000,
#      'description': {'beds': 5,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/05aa4bee76bb97a6ee6dcbd52769f9f0l-m3081781253s.jpg'},
#      'permalink': '87-Wildwood-Dr_Dix-Hills_NY_11746_M43553-82664',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/87-Wildwood-Dr_Dix-Hills_NY_11746_M43553-82664',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Dix Hills',
#        'country': 'USA',
#        'line': '87 Wildwood Dr',
#        'postal_code': '11746',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'white center island kitchen with honed Danby Imperial Marble',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'entry foyer with panels',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'large walk in pantry',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'formal dining room',
#        'text': 'Stately brick Colonial with incredible curb appeal, spacious circular driveway w/ columns & archways lead you to this completely redone home with a open floor plan, pretty entry foyer with panels & exquisite moldings, radiant wide plank oak floors, coffered ceilings, stunning white center island kitchen with honed Danby Imperial Marble, Thermador appliances, large walk in pantry dining area that connects to the family room w/ wood burning Travertine fireplace, living room & formal dining room, 1st flr home office w/ hi ceilings & half bath.'},
#       {'phrase': 'great storage',
#        'text': 'Upstairs a gorgeous primary bedroom suite w/ electric fireplace, custom designed closets, master bath w/ radiant heat, generous size bedrooms each w/ a WIC, Finished basement w/ rec space, full bath, laundry, wet bar & great storage, Completely loaded backyard w/ Gunite htd, salt pool, outdoor kitchen w/ gas BBQ, cooktop, ice maker, full sink & fridge, covered pavilion, outdoor cedar bathroom, koi pond, prof landscaping, turn key!'}]},
#     {'property_id': '9942955464',
#      'list_price': 1200000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3600},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/bdaf8ccae19201e9ebe9c91aa7598661l-b2756429838s.jpg'},
#      'permalink': '33A-Cove-Rd-A_Huntington_NY_11743_M99429-55464',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/33A-Cove-Rd-A_Huntington_NY_11743_M99429-55464',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Huntington',
#        'country': 'USA',
#        'line': '33A Cove Rd Unit A',
#        'postal_code': '11743',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Gourmet white Kitchen granite counter top with stainless steel top',
#        'text': 'The heart of the house has a Gourmet white Kitchen granite counter top with stainless steel top of the line appliances .'},
#       {'phrase': 'Luxurious Master Suite with tray ceiling wall',
#        'text': 'Luxurious Master Suite with tray ceiling wall of windows with electric blinds & Extraordinary double Walk-in Closet!'},
#       {'phrase': 'Grand 2 Story Entry Way with double closets',
#        'text': 'The Grand 2 Story Entry Way with double closets along with quality moldings and doors Leads Into this Gorgeous 4 Bedroom, 3.5 Bathroom Home.'},
#       {'phrase': 'separate stall shower with double sink vanity',
#        'text': 'The master bath has a sumptuous tub and a separate stall shower with double sink vanity.'},
#       {'phrase': 'sumptuous tub',
#        'text': 'The master bath has a sumptuous tub and a separate stall shower with double sink vanity.'}]},
#     {'property_id': '4068836272',
#      'list_price': 18995000,
#      'description': {'beds': 6,
#       'baths': 8,
#       'baths_full': 7,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 8000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/9349cca6e7b52b85b794a5fab6626a30l-b2618697360s.jpg'},
#      'permalink': '67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '67 Hither Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spectacular gas fireplace with exquisite antique mill work',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'formal living room design is inspired by London',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique mill work and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar and custom high gloss lacquer Varenna mill work',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'oversized upstairs media room',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'high gloss lacquered ceilings with ornamental antique molding',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'formal dining room',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'uber sexy kitchen lounge area',
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': "butler 's pantry",
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': 'spacious main floor primary suite',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'two custom lit closets',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'pool pavilion with full bath',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'south side of the property',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'wide gunite pool',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within ear shot of the ocean waves."},
#       {'phrase': 'wide custom fireplace',
#        'text': "The outdoor living pavilion has 14' soaring ceilings, a 12' granite clad summer kitchen with refrigerator/sink/bbq, a 16' wide custom fireplace with floating hearth and accent lighting, all anchored by a sensational 25' infinity edge gunite salt water spa."},
#       {'phrase': 'double glass entry doors',
#        'text': "The Italian-stone clad postman's walk leads to a steel architectural canopy which floats above the double glass entry doors."},
#       {'phrase': 'front entry garden',
#        'text': 'Upon arrival, visitors are greeted with an impressively scaled 5000 lb sculpture, commissioned for the front entry garden.'},
#       {'phrase': 'proportioned suites with generous closets',
#        'text': 'Guests will enjoy well proportioned suites with generous closets, motion lighting and Duravit baths.'},
#       {'phrase': 'one half car heated garage',
#        'text': 'Additional amenities include surveillance, gym, wine room, sauna, cedar closets, two and one half car heated garage, central vac, smart irrigation, Lutron lighting, and custom audio inside and out.'},
#       {'phrase': 'heated glass roof atrium',
#        'text': 'The exterior design highlights three main areas: The heated glass roof atrium connects the main house via sliding glass walls to the outdoor dining pavilion.'}]},
#     {'property_id': '3781242032',
#      'list_price': 349900,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 1,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 1344},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/5f814bf37dfca74d7d085feaf0231269l-m2787402958s.jpg'},
#      'permalink': '55-Macarthur-Ave_Brentwood_NY_11717_M37812-42032',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/55-Macarthur-Ave_Brentwood_NY_11717_M37812-42032',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Brentwood',
#        'country': 'USA',
#        'line': '55 Macarthur Ave',
#        'postal_code': '11717',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': [{'start_date': '2022-11-27T11:00:00',
#        'end_date': '2022-11-27T15:00:00'},
#       {'start_date': '2022-11-29T17:00:00',
#        'end_date': '2022-11-29T19:00:00'}],
#      'sentences_list': [{'phrase': 'nice wide block with brand new roof and brand new windows',
#        'text': 'North Brentwood colonial on a very nice wide block with brand new roof and brand new windows.'},
#       {'phrase': 'Huge yard', 'text': 'Huge yard at .'}]},
#     {'property_id': '3533730752',
#      'list_price': 667000,
#      'description': {'beds': 4,
#       'baths': 3,
#       'baths_full': 2,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/d87f2965d0ea9d82112e1b258b1d3300l-m2553493474s.jpg'},
#      'permalink': '11-Redleaf-Ln_Commack_NY_11725_M35337-30752',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/11-Redleaf-Ln_Commack_NY_11725_M35337-30752',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': True,
#       'is_plan': None},
#      'location': {'address': {'city': 'Commack',
#        'country': 'USA',
#        'line': '11 Redleaf Ln',
#        'postal_code': '11725',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'levels Features BRAND NEW custom Eat in kitchen',
#        'text': 'Boasts bright open floor plan with vaulted ceilings on both levels Features BRAND NEW custom Eat in kitchen w/light Cabinetry w/soft close draws, S.S.'},
#       {'phrase': 'open floor plan with vaulted ceilings',
#        'text': 'Boasts bright open floor plan with vaulted ceilings on both levels Features BRAND NEW custom Eat in kitchen w/light Cabinetry w/soft close draws, S.S.'},
#       {'phrase': 'Granite counter tops with ample space',
#        'text': 'appliances, Granite counter tops with ample space, backslash, 2.5 baths, windows, all flooring, Boiler, exterior door & kitchen slider, driveway, gutters, walkways, patio pavers, cesspool, washer, dryer, 4 AC units.'}]},
#     {'property_id': '3647622809',
#      'list_price': 639000,
#      'description': {'beds': 6,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/8bb5fa5084b484734e1cf8c6eb8cd13al-m598323910s.jpg'},
#      'permalink': '62-Laurie-Rd_Brentwood_NY_11717_M36476-22809',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/62-Laurie-Rd_Brentwood_NY_11717_M36476-22809',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Brentwood',
#        'country': 'USA',
#        'line': '62 Laurie Rd',
#        'postal_code': '11717',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'new stainless steel appliances surrounded by brand new kitchen with tons',
#        'text': 'This home boasts freshly polished hardwood floors, brand new stainless steel appliances surrounded by brand new kitchen with tons of storage, granite countertop and marble backsplash.'},
#       {'phrase': 'Huge backyard with additional space',
#        'text': 'Huge backyard with additional space behind the fence.'},
#       {'phrase': 'desirable Brentwood neighborhood',
#        'text': 'Welcome to a fully renovated 6 Bedroom, 2 bathroom house in a desirable Brentwood neighborhood.'}]},
#     {'property_id': '4124648059',
#      'list_price': 3495000,
#      'description': {'beds': 5,
#       'baths': 5,
#       'baths_full': 5,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 3877},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/639044074a34c4ced5bc72b3729fb80el-m1166864234s.jpg'},
#      'permalink': '49-Cosdrew-Ln_East-Hampton_NY_11937_M41246-48059',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/49-Cosdrew-Ln_East-Hampton_NY_11937_M41246-48059',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '49 Cosdrew Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Spacious family kitchen with high end Bertazzoni appliances',
#        'text': 'Spacious family kitchen with high end Bertazzoni appliances.'},
#       {'phrase': 'Junior Primary suite',
#        'text': 'There is a Junior Primary suite on the first floor in addition to 4 ensuite bedrooms on the second floor.'},
#       {'phrase': 'beautiful privacy as this property',
#        'text': 'It will have an 18 by 36 gunite pool and beautiful privacy as this property abuts a nature preserve!'},
#       {'phrase': '36 gunite pool',
#        'text': 'It will have an 18 by 36 gunite pool and beautiful privacy as this property abuts a nature preserve!'}]},
#     {'property_id': '3522803057',
#      'list_price': 2595000,
#      'description': {'beds': 4,
#       'baths': 4,
#       'baths_full': 3,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/adf6856646cad6fa3ddd09ca618fd314l-m131787748s.jpg'},
#      'permalink': '23-Long-Hill-Rd_East-Hampton_NY_11937_M35228-03057',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/23-Long-Hill-Rd_East-Hampton_NY_11937_M35228-03057',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '23 Long Hill Rd',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': [{'start_date': '2022-11-26T11:30:00',
#        'end_date': '2022-11-26T13:00:00'}],
#      'sentences_list': [{'phrase': 'expansive first floor primary suite offers plenty of privacy',
#        'text': 'The expansive first floor primary suite offers plenty of privacy and a large spa-like bath with new vanities, cabinetry and countertops.'},
#       {'phrase': 'cabinetry and countertops',
#        'text': 'The expansive first floor primary suite offers plenty of privacy and a large spa-like bath with new vanities, cabinetry and countertops.'},
#       {'phrase': 'expansive Timbertech deck',
#        'text': 'Ideal for entertaining, a bank of sliders lead you to a new and expansive Timbertech deck, heated pool and hot tub surrounded by lush landscaping.'},
#       {'phrase': 'hot tub',
#        'text': 'Ideal for entertaining, a bank of sliders lead you to a new and expansive Timbertech deck, heated pool and hot tub surrounded by lush landscaping.'},
#       {'phrase': "chef 's kitchen",
#        'text': "The chef's kitchen features new quartz countertops and high-end appliances."}]},
#     {'property_id': '9200255023',
#      'list_price': 19950000,
#      'description': {'beds': 12,
#       'baths': 12,
#       'baths_full': 12,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': 15000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/a65100c13347ce2b0384a95a90ea2379l-m636774261s.jpg'},
#      'permalink': '180-Rose-Hill-Rd_Water-Mill_NY_11976_M92002-55023',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/180-Rose-Hill-Rd_Water-Mill_NY_11976_M92002-55023',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Water Mill',
#        'country': 'USA',
#        'line': '180 Rose Hill Rd',
#        'postal_code': '11976',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'formal dining room with a buffet server and two elegant glass wine displays',
#        'text': 'Fully equipped with a gourmet chefÃ¢â‚¬â„¢s kitchen, and a formal dining room with a buffet server and two elegant glass wine displays.'},
#       {'phrase': 'main level junior master suite',
#        'text': 'The main level junior master suite includes a lounge area with a fireplace, a private balcony, a sizeable walk-in closet, and en-suite bathroom.'},
#       {'phrase': 'private balcony',
#        'text': 'The main level junior master suite includes a lounge area with a fireplace, a private balcony, a sizeable walk-in closet, and en-suite bathroom.'},
#       {'phrase': 'outdoor lounge with a fireplace',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'expansive outdoor patio',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'outdoor kitchen',
#        'text': "The expansive outdoor patio embraces the 22' x 65' swimming pool with a sundeck, oversized 12' by 20' spa, alongside a 2,000 sqft poolside pavilion with an outdoor kitchen and an outdoor lounge with a fireplace."},
#       {'phrase': 'lounge area with a fireplace',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'lavish master suite',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'large balcony',
#        'text': 'The second level accommodates the lavish master suite, also offering a lounge area with a fireplace, a large balcony, a generous walk-in closet, and full spa-inspired bathroom.'},
#       {'phrase': 'additional home office',
#        'text': 'The pool house incorporates an additional indoor/outdoor kitchen, indoor/outdoor lounge, fitness center/yoga studio, additional home office, and full bathroom making entertaining opportunities endless.'},
#       {'phrase': 'formal bar',
#        'text': 'The main level offers a double-height ceiling living room with a formal bar, fireplace, and access to the expansive poolside terrace.'}]},
#     {'property_id': '4154571724',
#      'list_price': 3695000,
#      'description': {'beds': 5,
#       'baths': 6,
#       'baths_full': 5,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 3877},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/814167c01f3610830032ad188feab56cl-m1308755400s.jpg'},
#      'permalink': '18-Barnes-Ave_East-Hampton_NY_11937_M41545-71724',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/18-Barnes-Ave_East-Hampton_NY_11937_M41545-71724',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '18 Barnes Ave',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Spacious family kitchen with high end Bertazzoni appliances',
#        'text': 'Spacious family kitchen with high end Bertazzoni appliances.'},
#       {'phrase': '32 gunite pool',
#        'text': 'It will have an 18 by 32 gunite pool.'}]},
#     {'property_id': '4072798171',
#      'list_price': 399000,
#      'description': {'beds': 2,
#       'baths': 2,
#       'baths_full': 1,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 869},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/18c6953d02103c5e76ab17c4642fac39l-m411612604s.jpg'},
#      'permalink': '188-Kingston-Dr_Ridge_NY_11961_M40727-98171',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/188-Kingston-Dr_Ridge_NY_11961_M40727-98171',
#      'flags': {'is_pending': True,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Ridge',
#        'country': 'USA',
#        'line': '188 Kingston Dr Unit 188',
#        'postal_code': '11961',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Custom white wood cabinets with soft close drawers',
#        'text': 'Custom white wood cabinets with soft close drawers.'},
#       {'phrase': 'Glen Cove Model with expanded garage space',
#        'text': 'Lovely Glen Cove Model with expanded garage space and pull down attic steps .'},
#       {'phrase': 'attic steps',
#        'text': 'Lovely Glen Cove Model with expanded garage space and pull down attic steps .'},
#       {'phrase': 'Granite counter tops and Stainless appliances',
#        'text': 'Granite counter tops and Stainless appliances.'},
#       {'phrase': 'Rear patio and front',
#        'text': 'Rear patio and front covered porch.'},
#       {'phrase': 'windows and roof',
#        'text': 'The siding, windows and roof have all been replaced 2018.'}]},
#     {'property_id': '4697368030',
#      'list_price': 875000,
#      'description': {'beds': 3,
#       'baths': 2,
#       'baths_full': 2,
#       'baths_half': None,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/6836c007ed316ae73a948ab5121c1294l-m1936919759s.jpg'},
#      'permalink': '516-Madison-Ave_Greenport_NY_11944_M46973-68030',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/516-Madison-Ave_Greenport_NY_11944_M46973-68030',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': True,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Greenport',
#        'country': 'USA',
#        'line': '516 Madison Ave',
#        'postal_code': '11944',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'Open floor plan with spacious double height living room centered on wood',
#        'text': 'Open floor plan with spacious double height living room centered on wood burning fireplace.'},
#       {'phrase': 'full width rear deck',
#        'text': 'Inviting front porch and full width rear deck.'},
#       {'phrase': 'front porch',
#        'text': 'Inviting front porch and full width rear deck.'},
#       {'phrase': 'ample room for a pool',
#        'text': 'Light and bright Greenport Village two story Farmhouse set on rarely available deep and very private double lot with ample room for a pool and backing onto Silver Lake preserved land.'}]},
#     {'property_id': '3542840089',
#      'list_price': 1095000,
#      'description': {'beds': 4,
#       'baths': 3,
#       'baths_full': 2,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': None},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/f0b512a17c84bb45856968b64a1793a9l-m567448271s.jpg'},
#      'permalink': '505-Saltaire-Way_Mattituck_NY_11952_M35428-40089',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/505-Saltaire-Way_Mattituck_NY_11952_M35428-40089',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'Mattituck',
#        'country': 'USA',
#        'line': '505 Saltaire Way',
#        'postal_code': '11952',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'beautiful white shaker kitchen with real marble countertops',
#        'text': 'The first floor boasts a stunning open floor plan, beautiful white shaker kitchen with real marble countertops, great room with gas fireplace and a large master bedroom with stunning en-suite bathroom.'},
#       {'phrase': 'great room with gas fireplace',
#        'text': 'The first floor boasts a stunning open floor plan, beautiful white shaker kitchen with real marble countertops, great room with gas fireplace and a large master bedroom with stunning en-suite bathroom.'},
#       {'phrase': 'ample space for pool',
#        'text': 'Private fully fenced in backyard with ample space for pool!'}]},
#     {'property_id': '4068836272',
#      'list_price': 18995000,
#      'description': {'beds': 6,
#       'baths': 8,
#       'baths_full': 7,
#       'baths_half': 1,
#       'baths_3qtr': None,
#       'sqft': 8000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/9349cca6e7b52b85b794a5fab6626a30l-b2618697360s.jpg'},
#      'permalink': '67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/67-Hither-Ln_East-Hampton_NY_11937_M40688-36272',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': None,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '67 Hither Ln',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'spectacular gas fireplace with exquisite antique millwork',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'formal living room design is inspired by London',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar',
#        'text': "The formal living room design is inspired by London's finest hotels and features lacquered wood-paneled walls with architectural lighting embedded in chair rail molding, wet bar with bronze glass, spectacular gas fireplace with exquisite antique millwork and Italian quartzite stone hearth and surround, intuitive mood lighting, and motorized pinstriped linen shades concealed beneath ornate crown molding."},
#       {'phrase': 'wet bar and custom high gloss lacquer Varenna mill work',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'oversized upstairs media room',
#        'text': 'The oversized upstairs media room features a projection screen theater, full bath, wet bar and custom high gloss lacquer Varenna mill work.'},
#       {'phrase': 'high gloss lacquered ceilings with ornamental antique molding',
#        'text': 'The formal dining room is punctuated with backlit custom Italian, transparent quartzite stone wall panels with floating glass shelves, stone fireplace, high gloss lacquered ceilings with ornamental antique molding and motorized window screens.'},
#       {'phrase': 'uber sexy kitchen lounge area',
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top-notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': "butler 's pantry",
#        'text': "The show stopping kitchen has custom Poliform/Varenna cabinetry, top-notch Wolf and Miele appliances, butler's pantry and an uber sexy kitchen lounge area featuring Marcel Wanders sofa and chairs."},
#       {'phrase': 'spacious main floor primary suite',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'two custom lit closets',
#        'text': 'The bright, spacious main floor primary suite offers a calming retreat with motorized drapes, sitting area, sculpture garden, spa bath with mirrored TV, heated stone flooring, glass front double vanities, senso wash Duravit bidet, motion lighting sensors and two custom lit closets.'},
#       {'phrase': 'pool pavilion with full bath',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'south side of the property',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'wide gunite pool',
#        'text': "The south side of the property boasts a pool pavilion with full bath, outdoor shower and generously proportioned 25' wide gunite pool all within earshot of the ocean waves."},
#       {'phrase': 'wide custom fireplace',
#        'text': "The outdoor living pavilion has 14' soaring ceilings, a 12' granite clad summer kitchen with refrigerator/sink/bbq, a 16' wide custom fireplace with floating hearth and accent lighting, all anchored by a sensational 25' infinity edge gunite saltwater spa."},
#       {'phrase': 'double glass entry doors',
#        'text': "The Italian-stone clad postman's walk leads to a steel architectural canopy that floats above the double glass entry doors."},
#       {'phrase': 'front entry garden',
#        'text': 'Upon arrival, visitors are greeted with an impressively scaled 5000 lb sculpture, commissioned for the front entry garden.'},
#       {'phrase': 'one half car heated garage',
#        'text': 'Additional amenities include surveillance, gym, wine room, sauna, cedar closets, two and one half car heated garage, central vac, smart irrigation, Lutron lighting, and custom audio inside and out.'},
#       {'phrase': 'heated glass roof atrium',
#        'text': 'The exterior design highlights three main areas: The heated glass roof atrium connects the main house via sliding glass walls to the outdoor dining pavilion.'},
#       {'phrase': 'generous closets',
#        'text': 'Guests will enjoy well-proportioned suites with generous closets, motion lighting and Duravit baths.'},
#       {'phrase': 'formal dining room',
#        'text': 'Enter the grand foyer into a spacious open-concept custom home ideal for family and entertaining with a formal dining room, living room and family room that flow seamlessly from one room to the next.'}]},
#     {'property_id': '3651483610',
#      'list_price': 4495000,
#      'description': {'beds': 4,
#       'baths': 6,
#       'baths_full': 4,
#       'baths_half': 2,
#       'baths_3qtr': None,
#       'sqft': 3196},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/801f48c93dc2151c9b2b29d1193f476fl-b3206596477s.jpg'},
#      'permalink': '55-Gould-St_East-Hampton_NY_11937_M36514-83610',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/55-Gould-St_East-Hampton_NY_11937_M36514-83610',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': None,
#       'is_new_listing': False,
#       'is_price_reduced': True,
#       'is_plan': None},
#      'location': {'address': {'city': 'East Hampton',
#        'country': 'USA',
#        'line': '55 Gould St',
#        'postal_code': '11937',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': '2 bonus super sleek glass retractable garage doors',
#        'text': 'An added feature to 55 Gould is the attached heated luxury garage that can house up to six cars with 2 bonus super sleek glass retractable garage doors and expertly finished epoxy flooring.'},
#       {'phrase': 'attached heated luxury garage',
#        'text': 'An added feature to 55 Gould is the attached heated luxury garage that can house up to six cars with 2 bonus super sleek glass retractable garage doors and expertly finished epoxy flooring.'},
#       {'phrase': 'retractable pool cover',
#        'text': 'Step outside to your new 18x34 heated gunite pool with spa and salt water filtration and retractable pool cover.'},
#       {'phrase': 'gunite pool with spa',
#        'text': 'Step outside to your new 18x34 heated gunite pool with spa and salt water filtration and retractable pool cover.'},
#       {'phrase': 'luxurious primary suite',
#        'text': 'The second level boasts 3 en-suite bedrooms, the 4th bedroom with full hall bath and the luxurious primary suite with vaulted ceilings, walk-in closet and custom bathroom.'},
#       {'phrase': 'outdoor grill and bar',
#        'text': 'Host your guests around the floating outdoor grill and bar set up or bask in the sun around the pool with gorgeous bluestone hardscape.'},
#       {'phrase': 'pool bath and laundry',
#        'text': 'One of the 2 half baths is located right off the kitchen that is also a pool bath and laundry.'},
#       {'phrase': 'honed carrara waterfall island',
#        'text': 'The first floor includes an inviting entryway, dining room, living room with fireplace, and an over-sized gourmet kitchen with a honed carrara waterfall island that opens into a sun drenched sitting room, making conversation easy when entertaining or just hanging with the iPad and your morning cup of coffee.'}]},
#     {'property_id': '9135534016',
#      'list_price': 27500000,
#      'description': {'beds': 11,
#       'baths': 17,
#       'baths_full': 15,
#       'baths_half': 2,
#       'baths_3qtr': None,
#       'sqft': 23000},
#      'primary_photo': {'href': 'https://ap.rdcpix.com/5ac10a3b67942c37eedede3ddb03c3a6l-m214815142s.jpg'},
#      'permalink': '802-Town-Line-Rd_Sagaponack_NY_11962_M91355-34016',
#      'href': 'https://www.realtor.com/realestateandhomes-detail/802-Town-Line-Rd_Sagaponack_NY_11962_M91355-34016',
#      'flags': {'is_pending': None,
#       'is_foreclosure': None,
#       'is_contingent': None,
#       'is_new_construction': True,
#       'is_new_listing': False,
#       'is_price_reduced': False,
#       'is_plan': None},
#      'location': {'address': {'city': 'Sagaponack',
#        'country': 'USA',
#        'line': '802 Town Line Rd',
#        'postal_code': '11962',
#        'state_code': 'NY',
#        'state': 'New York'}},
#      'open_houses': None,
#      'sentences_list': [{'phrase': 'second floor primary suite features two full bathrooms',
#        'text': 'Encompassing the northern wing of the main residence, the second floor primary suite features two full bathrooms with Polish glass tile floors and full custom marble slabs on the bath and shower walls, massage room, two walk-in closets, a private office/sitting room, and a private balcony.'},
#       {'phrase': 'private balcony',
#        'text': 'Encompassing the northern wing of the main residence, the second floor primary suite features two full bathrooms with Polish glass tile floors and full custom marble slabs on the bath and shower walls, massage room, two walk-in closets, a private office/sitting room, and a private balcony.'},
#       {'phrase': 'lower level kitchen',
#        'text': 'Two ensuite bedrooms are ideally positioned near the lower level kitchen and secondary staircase, which leads up to the main floor gym.'},
#       {'phrase': 'secondary staircase',
#        'text': 'Two ensuite bedrooms are ideally positioned near the lower level kitchen and secondary staircase, which leads up to the main floor gym.'},
#       {'phrase': 'own wet bar',
#        'text': 'The luxurious living room seamlessly transitions into a formal dining area with seating for ten and its own wet bar.'},
#       {'phrase': 'luxurious living room',
#        'text': 'The luxurious living room seamlessly transitions into a formal dining area with seating for ten and its own wet bar.'},
#       {'phrase': 'great room with soaring ceilings',
#        'text': 'With over 19, 000 square feet, the main residence is introduced by an entry foyer leading to a majestic great room with soaring ceilings featuring a double-sided Galvalume Steel Cladded fireplace designed by local Sagaponack artist, Nathan Slate Joseph and floor-to-ceiling windows showcasing unobstructed reserve views.'},
#       {'phrase': 'primary suite',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'separate balcony',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'laundry room',
#        'text': 'Joining the primary suite on the second floor are three ensuite bedrooms each with access to a separate balcony, two sitting rooms, laundry room, and guest quarters comprised of two ensuite bedrooms and an office which share an eastern-facing deck.'},
#       {'phrase': 'custom storage units',
#        'text': "Surrounded by a Madras patio, the 60' x 25' heated salt water gunite pool with 12' x 8' spa offers ample space for poolside relaxation and the professional-sized sunken Har-Tru tennis court is equipped with a hydro underground system and custom storage units."},
#       {'phrase': 'gunite pool',
#        'text': "Surrounded by a Madras patio, the 60' x 25' heated salt water gunite pool with 12' x 8' spa offers ample space for poolside relaxation and the professional-sized sunken Har-Tru tennis court is equipped with a hydro underground system and custom storage units."},
#       {'phrase': 'expansive living area',
#        'text': 'Inside the refurbished structure is an expansive living area, kitchen, full bathroom and additional storage below.'},
#       {'phrase': 'additional storage below',
#        'text': 'Inside the refurbished structure is an expansive living area, kitchen, full bathroom and additional storage below.'},
#       {'phrase': 'stainless steel Boffi cabinets with a multitude',
#        'text': 'The main level hosts a gourmet dine-in kitchen, open to a relaxed seating area, and offers stainless steel Boffi cabinets with a multitude of high-end appliances.'},
#       {'phrase': 'junior suite',
#        'text': 'The first floor is completed by an enclosed wine room, junior suite, office, and two powder rooms.'},
#       {'phrase': 'main living area',
#        'text': 'Set outside the main living area is a patio with outdoor fire pit capable of seating 30 people and accentuated by the complete exterior lighting package.'},
#       {'phrase': 'recreational room with pool table',
#        'text': 'A recreational room with pool table provides access to an outdoor dining area and is joined by an ensuite bedroom.'}]}]}}}
